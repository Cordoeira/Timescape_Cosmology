# %% [markdown]
# The purpose of this Notebook is to test and analyze cosmological models and verify the correct call of the function that defines them.
#
# For this, we're going to set the mathematical background for each model before setting to show what is the equation and which observables and parameters are going to be infered.

# %%
def timescape(z, H_bar, Omega_m0, f_v0, alpha, beta, gamma):
    ## equações e definições.
